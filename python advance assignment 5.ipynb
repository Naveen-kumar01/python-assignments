# %% [markdown]
# Q1. What is the meaning of multiple inheritance?

# %% [markdown]
# Ans - When a single child class inherits from more than 1 base class then it is called multiple inheritance.

# %%
class A:
    def Disp(self):
        print("Inside Class A")

class B():
    def Disp(self):
        print("Inside Class B")

class C(A,B):
    def Disp(self):
        print("Inside Class C") 
     
obj = C()
obj.Disp()
# Out:
# Inside Class C

# %% [markdown]
# Q2. What is the concept of delegation?

# %% [markdown]
# Ans - Delegation is an object oriented technique. let x be an object you want to change the function of just one of its
#       methods. You can create a new class that provides a new definition of the method you are interested in changing
#       and delegates all other methods to the corresponding method of x.

# %% [markdown]
# Q3. What is the concept of composition?

# %% [markdown]
# Ans - Composition is a concept that describe a, 'has a' relationship. It enables creating complex types by combining objects of
#       other types. This means that a class Composite can contain an object of another class Component. This relationship
#       means that a Composite has a Component.
#       In this concept, we will describe a class that references to one or more objects of other classes as an Instance
#       variable. Here, by using the class name or by creating the object we can access the members of one class inside
#       another class.

# %% [markdown]
# Q4. What are bound methods and how do we use them?

# %% [markdown]
# Ans - In the bound methods, the instance obj is passed by itself as the first argument to the function called and hence the
#       first parameter of the function will be used to reach all the variables/functions of the object.
#       All the new version of the python which are 3.0 and above have methods that are by default bound methods.

# %% [markdown]
# Q5. What is the purpose of pseudoprivate attributes?

# %% [markdown]
# Ans - The purpose of using pseudoprivate attributes is to avoid introducing new method names that might accidentally hide
#       definitions and also to reduce the chance of internal methods being replaced by names defined lower in the tree.
#       In Python, all instance attributes wind up in the single instance object at the bottom of the class tree. The value
#       of the self variable is modified by the last method it was called by.
