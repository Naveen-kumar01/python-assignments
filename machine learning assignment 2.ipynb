# %% [markdown]
# Q1. What is the concept of human learning? Please give two examples.

# %% [markdown]
# Ans - The humans learn by visualising, audio analysing, reading and writing. The human start learning from birth, when they are       small they try to learn through visualising things, and when they grow they try to understand and increase there knowledge       by reading ,writing and analysing things.

# %% [markdown]
# Q2. What different forms of human learning are there? Are there any machine learning equivalents?

# %% [markdown]
# Ans - Supervised learning is similar to concept learning, where a person is required to classify new objects into existing             categories, by matching the features of the new objects to examples in the categories.
#       Reinforcement learning is inspired by the reward system of operant conditioning, just like in the maze, they can go             anywhere but they try and choose the right path by committing mistake.

# %% [markdown]
# Q3. What is machine learning, and how does it work? What are the key responsibilities of machine learning?

# %% [markdown]
# Ans - The machine learning is a part of the AI. The machine learning focuses on learning the relationship that is established         between the features and the target variable. There are various kind of machine learning algorithms that help us to study       and identify these relationship. There is supervised, unsupervised and semisupervised learning.

# %% [markdown]
# Q4. Define the terms penalty and reward in the context of reinforcement learning.

# %% [markdown]
# Ans - The term penality is used for every wrong decision and term reward is used for every correct decision.

# %% [markdown]
# Q5. Explain the term 'learning as a search'?

# %% [markdown]
# Ans - machine learning is challenging because the designing of a perfect learning system for a given problem in intractable.           There is no best training data or best algorithm for your problem, only the best that you can discover.

# %% [markdown]
# Q6. What are the various goals of machine learning? What is the relationship between these and human learning?

# %% [markdown]
# Ans - The main aim of machine learning is to analyse the data and study the patternthat is followd by the data in order to come       up with a model which can predict accuratly the data in new instances.
#       Supervised learning is similar to concept learning, where a person is required to classify new objects into existing             categories, by matching the features of the new objects to examples in the categories.

# %% [markdown]
# Q7. Illustrate the various elements of machine learning using a real-life illustration.

# %% [markdown]
# Ans - The elements that are present in ML are representation which is equivalent to visualisation, optimisation which is               equivalent to error finding, evaluation which involes hypothesis testing .

# %% [markdown]
# Q8. Provide an example of the abstraction method.

# %% [markdown]
# Ans - The abstraction method is the function which does not include any body and it must be implemeted in the inherited class         otherwise it throws exception error. the class that contain such method is called abstract class.

# %% [markdown]
# Q9. What is the concept of generalization? What function does it play in the machine learning process?

# %% [markdown]
# Ans - The term generalisation is used for the model we are using for prediction if the model is not overfited and underfitted  it will give good test set accuracy, then we conclude that our model is generalising well on the test set.

# %% [markdown]
# Q10. What is classification, exactly? What are the main distinctions between classification and regression?

# %% [markdown]
# Ans - The classification problem are mainly used for predicting a discrete class label. Regression is the task of predicting a         continuous quantity.

# %% [markdown]
# Q11. What is regression, and how does it work? Give an example of a real-world problem that was solved using regression.

# %% [markdown]
# Ans - The regression is method used for predicting the interval/ratio data, like the price of the house or predicting the             temperature. These kind of problem are solved using regression. We try to analyse the relationship between various feature       and how they affect the target feature. The linear regression is on example of regression algorithms. The linear                 regression work on the residual error in the data.

# %% [markdown]
# Q12. Describe the clustering mechanism in detail.

# %% [markdown]
# Ans - The clustering is used to classify the data into various gropus/category that show similar behaviour to each other. It forms various clusters for different kind of groups, it uses the euclidean distance to calculate the distance between to points. This is what is called clustering. There are various algorithm of clustering like k means, dbscan, heirarchical clustering.

# %% [markdown]
# Q13. Make brief observations on two of the following topics:
#
# i. Machine learning algorithms are used
# ii. Studying under supervision
# iii. Studying without supervision
# iv. Reinforcement learning is a form of learning based on positive reinforcement.

# %% [markdown]
# Ans -
#      (i)The machine learning focuses on learning the relationship that is established between the features and the target               variable. There are various kind of machine learning algorithms that help us to study and identify these relationship.
#      (ii)The supervision is similar to supervised learning, which uses the target variable and the features to establish the              relationship between them and then generate prediction on the test data.
